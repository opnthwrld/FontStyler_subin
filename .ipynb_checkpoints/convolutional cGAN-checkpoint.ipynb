# %% [markdown]
# ### convolutional conditional GAN

# %%
import pandas as pd
import numpy as np
import pyreadr as py # library to read .Rdata files in python
import os
import tensorflow as tf
from time import time
import pickle
import datetime
import random
import math
import csv
import time
import sys

# %%
from sklearn.metrics import multilabel_confusion_matrix,confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler,Normalizer
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV,KFold
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,f1_score,log_loss,recall_score,classification_report
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data.dataset import Dataset  
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

# %%
from src.models.model import AE_base
from src.data.common.dataset import FontDataset, PickledImageProvider

# %%
import torch
from torch.nn import functional as F
from torch.optim import SGD, Adam
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

# %%
batch_size = 8
validation_split = .15
test_split = .05
shuffle_dataset = True
random_seed = 42

lr = 0.0001

log_interval = 10
epochs = 200

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from src.models.function import conv2d, deconv2d, batch_norm, lrelu, dropout
from src.data.common.dataset import NewFontDataset, PickledImageProvider, KoreanFontDataset

# %%
# get Dataset
data_dir = 'src/data/dataset/'
train_set = KoreanFontDataset(PickledImageProvider(data_dir+'train.obj'), vector_size=20)
valid_set = KoreanFontDataset(PickledImageProvider(data_dir+'val.obj'), vector_size=20)
test_set = KoreanFontDataset(PickledImageProvider(data_dir+'test.obj'), vector_size=20)
# Out:
# processed 1000 examples
# processed 2000 examples
# processed 3000 examples
# processed 4000 examples
# processed 5000 examples
# processed 6000 examples
# processed 7000 examples
# processed 8000 examples
# processed 9000 examples
# processed 10000 examples
# processed 11000 examples
# processed 12000 examples
# processed 13000 examples
# processed 14000 examples
# processed 15000 examples
# processed 16000 examples
# processed 17000 examples
# processed 18000 examples
# processed 19000 examples
# processed 20000 examples
# processed 21000 examples
# processed 22000 examples
# processed 23000 examples
# processed 24000 examples
# processed 25000 examples
# processed 26000 examples
# processed 27000 examples
# processed 28000 examples
# processed 29000 examples
# processed 30000 examples
# processed 31000 examples
# processed 32000 examples
# processed 33000 examples
# processed 34000 examples
# processed 35000 examples
# processed 36000 examples
# processed 37000 examples
# processed 38000 examples
# processed 39000 examples
# processed 40000 examples
# processed 41000 examples
# processed 42000 examples
# processed 43000 examples
# processed 44000 examples
# processed 45000 examples
# processed 46000 examples
# processed 47000 examples
# processed 48000 examples
# processed 49000 examples
# processed 50000 examples
# processed 51000 examples
# processed 52000 examples
# processed 53000 examples
# processed 54000 examples
# processed 55000 examples
# processed 56000 examples
# processed 57000 examples
# processed 58000 examples
# processed 59000 examples
# processed 60000 examples
# processed 61000 examples
# processed 62000 examples
# processed 63000 examples
# processed 64000 examples
# processed 65000 examples
# processed 66000 examples
# processed 67000 examples
# processed 68000 examples
# processed 69000 examples
# processed 70000 examples
# processed 71000 examples
# processed 72000 examples
# processed 73000 examples
# processed 74000 examples
# processed 75000 examples
# processed 76000 examples
# processed 77000 examples
# processed 78000 examples
# processed 79000 examples
# processed 80000 examples
# processed 81000 examples
# processed 82000 examples
# processed 83000 examples
# processed 84000 examples
# processed 85000 examples
# processed 86000 examples
# processed 87000 examples
# processed 88000 examples
# processed 89000 examples
# processed 90000 examples
# processed 91000 examples
# processed 92000 examples
# processed 93000 examples
# processed 94000 examples
# processed 95000 examples
# processed 96000 examples
# processed 97000 examples
# processed 98000 examples
# processed 99000 examples
# processed 100000 examples
# processed 101000 examples
# processed 102000 examples
# processed 103000 examples
# processed 104000 examples
# processed 105000 examples
# processed 106000 examples
# processed 107000 examples
# processed 108000 examples
# processed 109000 examples
# processed 110000 examples
# processed 111000 examples
# processed 112000 examples
# processed 113000 examples
# processed 114000 examples
# processed 115000 examples
# processed 116000 examples
# processed 117000 examples
# processed 118000 examples
# processed 119000 examples
# processed 120000 examples
# processed 121000 examples
# processed 122000 examples
# processed 123000 examples
# processed 124000 examples
# processed 125000 examples
# processed 126000 examples
# processed 127000 examples
# processed 128000 examples
# processed 129000 examples
# processed 130000 examples
# processed 131000 examples
# processed 132000 examples
# processed 133000 examples
# processed 134000 examples
# processed 135000 examples
# processed 136000 examples
# processed 137000 examples
# processed 138000 examples
# processed 139000 examples
# processed 140000 examples
# processed 141000 examples
# processed 142000 examples
# processed 143000 examples
# processed 144000 examples
# processed 145000 examples
# processed 146000 examples
# processed 147000 examples
# processed 148000 examples
# processed 149000 examples
# processed 150000 examples
# processed 151000 examples
# processed 152000 examples
# processed 153000 examples
# processed 154000 examples
# processed 155000 examples
# processed 156000 examples
# processed 157000 examples
# processed 158000 examples
# processed 159000 examples
# processed 160000 examples
# processed 161000 examples
# processed 162000 examples
# processed 163000 examples
# processed 164000 examples
# processed 165000 examples
# processed 166000 examples
# processed 167000 examples
# processed 168000 examples
# processed 169000 examples
# processed 170000 examples
# processed 171000 examples
# processed 172000 examples
# processed 173000 examples
# processed 174000 examples
# processed 175000 examples
# processed 176000 examples
# processed 177000 examples
# processed 178000 examples
# processed 179000 examples
# processed 180000 examples
# processed 181000 examples
# processed 182000 examples
# processed 183000 examples
# processed 184000 examples
# processed 185000 examples
# processed 186000 examples
# processed 187000 examples
# processed 188000 examples
# processed 189000 examples
# processed 190000 examples
# processed 191000 examples
# processed 192000 examples
# processed 193000 examples
# processed 194000 examples
# processed 195000 examples
# processed 196000 examples
# processed 197000 examples
# processed 198000 examples
# processed 199000 examples
# processed 200000 examples
# processed 201000 examples
# processed 202000 examples
# processed 203000 examples
# processed 204000 examples
# processed 205000 examples
# processed 206000 examples
# processed 207000 examples
# processed 208000 examples
# processed 209000 examples
# processed 210000 examples
# processed 211000 examples
# processed 212000 examples
# processed 213000 examples
# processed 214000 examples
# processed 215000 examples
# processed 216000 examples
# processed 217000 examples
# processed 218000 examples
# processed 219000 examples
# processed 220000 examples
# processed 221000 examples
# processed 222000 examples
# processed 223000 examples
# processed 224000 examples
# processed 225000 examples
# processed 226000 examples
# processed 227000 examples
# processed 228000 examples
# processed 229000 examples
# processed 230000 examples
# processed 231000 examples
# processed 232000 examples
# processed 233000 examples
# processed 234000 examples
# processed 235000 examples
# processed 236000 examples
# processed 237000 examples
# processed 238000 examples
# processed 239000 examples
# processed 240000 examples
# processed 241000 examples
# processed 242000 examples
# processed 243000 examples
# processed 244000 examples
# processed 245000 examples
# processed 246000 examples
# processed 247000 examples
# processed 248000 examples
# processed 249000 examples
# processed 250000 examples
# processed 251000 examples
# processed 252000 examples
# processed 253000 examples
# processed 254000 examples
# processed 255000 examples
# processed 256000 examples
# processed 257000 examples
# processed 258000 examples
# processed 259000 examples
# processed 260000 examples
# processed 261000 examples
# processed 262000 examples
# processed 263000 examples
# processed 264000 examples
# processed 265000 examples
# processed 266000 examples
# processed 267000 examples
# processed 268000 examples
# processed 269000 examples
# processed 270000 examples
# processed 271000 examples
# processed 272000 examples
# processed 273000 examples
# processed 274000 examples
# processed 275000 examples
# processed 276000 examples
# processed 277000 examples
# processed 278000 examples
# processed 279000 examples
# processed 280000 examples
# processed 281000 examples
# processed 282000 examples
# processed 283000 examples
# processed 284000 examples
# processed 285000 examples
# processed 286000 examples
# processed 287000 examples
# processed 288000 examples
# processed 289000 examples
# processed 290000 examples
# processed 291000 examples
# processed 292000 examples
# processed 293000 examples
# processed 294000 examples
# processed 295000 examples
# processed 296000 examples
# processed 297000 examples
# processed 298000 examples
# processed 299000 examples
# processed 300000 examples
# processed 301000 examples
# processed 302000 examples
# processed 303000 examples
# processed 304000 examples
# processed 305000 examples
# processed 306000 examples
# processed 307000 examples
# processed 308000 examples
# processed 309000 examples
# processed 310000 examples
# processed 311000 examples
# processed 312000 examples
# processed 313000 examples
# processed 314000 examples
# processed 315000 examples
# processed 316000 examples
# processed 317000 examples
# processed 318000 examples
# processed 319000 examples
# processed 320000 examples
# processed 321000 examples
# processed 322000 examples
# processed 323000 examples
# processed 324000 examples
# processed 325000 examples
# processed 326000 examples
# processed 327000 examples
# processed 328000 examples
# processed 329000 examples
# processed 330000 examples
# processed 331000 examples
# processed 332000 examples
# processed 333000 examples
# processed 334000 examples
# processed 335000 examples
# processed 336000 examples
# processed 337000 examples
# processed 338000 examples
# processed 339000 examples
# processed 340000 examples
# processed 341000 examples
# processed 342000 examples
# processed 343000 examples
# processed 344000 examples
# processed 345000 examples
# processed 346000 examples
# processed 347000 examples
# processed 348000 examples
# processed 349000 examples
# processed 350000 examples
# processed 351000 examples
# processed 352000 examples
# processed 353000 examples
# processed 354000 examples
# processed 355000 examples
# processed 356000 examples
# processed 357000 examples
# processed 358000 examples
# processed 359000 examples
# processed 360000 examples
# processed 361000 examples
# processed 362000 examples
# processed 363000 examples
# processed 364000 examples
# processed 365000 examples
# processed 366000 examples
# processed 367000 examples
# processed 368000 examples
# processed 369000 examples
# processed 370000 examples
# processed 371000 examples
# processed 372000 examples
# processed 373000 examples
# processed 374000 examples
# processed 375000 examples
# processed 376000 examples
# processed 377000 examples
# processed 378000 examples
# processed 379000 examples
# processed 380000 examples
# processed 381000 examples
# processed 382000 examples
# processed 383000 examples
# processed 384000 examples
# processed 385000 examples
# processed 386000 examples
# processed 387000 examples
# processed 388000 examples
# processed 389000 examples
# processed 390000 examples
# processed 391000 examples
# processed 392000 examples
# processed 393000 examples
# processed 394000 examples
# processed 395000 examples
# processed 396000 examples
# processed 397000 examples
# processed 398000 examples
# processed 399000 examples
# processed 400000 examples
# processed 401000 examples
# processed 402000 examples
# processed 403000 examples
# processed 404000 examples
# processed 405000 examples
# processed 406000 examples
# processed 407000 examples
# processed 408000 examples
# processed 409000 examples
# processed 410000 examples
# processed 411000 examples
# processed 412000 examples
# processed 413000 examples
# processed 414000 examples
# processed 415000 examples
# processed 416000 examples
# processed 417000 examples
# processed 418000 examples
# processed 419000 examples
# processed 420000 examples
# processed 421000 examples
# processed 422000 examples
# processed 423000 examples
# processed 424000 examples
# processed 425000 examples
# processed 426000 examples
# processed 427000 examples
# processed 428000 examples
# processed 429000 examples
# processed 430000 examples
# processed 431000 examples
# processed 432000 examples
# processed 433000 examples
# processed 434000 examples
# processed 435000 examples
# processed 436000 examples
# processed 437000 examples
# processed 438000 examples
# processed 439000 examples
# processed 440000 examples
# processed 441000 examples
# processed 442000 examples
# processed 443000 examples
# processed 444000 examples
# processed 445000 examples
# processed 446000 examples
# processed 447000 examples
# processed 448000 examples
# processed 449000 examples
# processed 450000 examples
# processed 451000 examples
# processed 452000 examples
# processed 453000 examples
# processed 454000 examples
# processed 455000 examples
# processed 456000 examples
# processed 457000 examples
# processed 458000 examples
# processed 459000 examples
# processed 460000 examples
# processed 461000 examples
# processed 462000 examples
# processed 463000 examples
# processed 464000 examples
# processed 465000 examples
# processed 466000 examples
# processed 467000 examples
# processed 468000 examples
# processed 469000 examples
# processed 470000 examples
# processed 471000 examples
# processed 472000 examples
# processed 473000 examples
# processed 474000 examples
# processed 475000 examples
# processed 476000 examples
# processed 477000 examples
# processed 478000 examples
# processed 479000 examples
# processed 480000 examples
# processed 481000 examples
# processed 482000 examples
# processed 483000 examples
# processed 484000 examples
# processed 485000 examples
# processed 486000 examples
# processed 487000 examples
# processed 488000 examples
# processed 489000 examples
# processed 490000 examples
# processed 491000 examples
# processed 492000 examples
# processed 493000 examples
# processed 494000 examples
# processed 495000 examples
# processed 496000 examples
# processed 497000 examples
# processed 498000 examples
# processed 499000 examples
# processed 500000 examples
# processed 501000 examples
# processed 502000 examples
# processed 503000 examples
# processed 504000 examples
# processed 505000 examples
# processed 506000 examples
# processed 507000 examples
# processed 508000 examples
# processed 509000 examples
# processed 510000 examples
# processed 511000 examples
# processed 512000 examples
# processed 513000 examples
# processed 514000 examples
# processed 515000 examples
# processed 516000 examples
# processed 517000 examples
# processed 518000 examples
# processed 519000 examples
# processed 520000 examples
# processed 521000 examples
# processed 522000 examples
# processed 523000 examples
# processed 524000 examples
# processed 525000 examples
# processed 526000 examples
# processed 527000 examples
# processed 528000 examples
# processed 529000 examples
# processed 530000 examples
# processed 531000 examples
# processed 532000 examples
# processed 533000 examples
# processed 534000 examples
# processed 535000 examples
# processed 536000 examples
# processed 537000 examples
# processed 538000 examples
# processed 539000 examples
# processed 540000 examples
# processed 541000 examples
# processed 542000 examples
# processed 543000 examples
# processed 544000 examples
# processed 545000 examples
# processed 546000 examples
# processed 547000 examples
# processed 548000 examples
# processed 549000 examples
# processed 550000 examples
# processed 551000 examples
# processed 552000 examples
# processed 553000 examples
# processed 554000 examples
# processed 555000 examples
# processed 556000 examples
# processed 557000 examples
# processed 558000 examples
# processed 559000 examples
# processed 560000 examples
# processed 561000 examples
# processed 562000 examples
# processed 563000 examples
# processed 564000 examples
# processed 565000 examples
# processed 566000 examples
# processed 567000 examples
# processed 568000 examples
# processed 569000 examples
# processed 570000 examples
# processed 571000 examples
# processed 572000 examples
# processed 573000 examples
# processed 574000 examples
# processed 575000 examples
# processed 576000 examples
# processed 577000 examples
# processed 578000 examples
# processed 579000 examples
# processed 580000 examples
# processed 581000 examples
# processed 582000 examples
# processed 583000 examples
# processed 584000 examples
# processed 585000 examples
# processed 586000 examples
# processed 587000 examples
# processed 588000 examples
# processed 589000 examples
# processed 590000 examples
# processed 591000 examples
# processed 592000 examples
# processed 593000 examples
# processed 594000 examples
# processed 595000 examples
# processed 596000 examples
# processed 597000 examples
# processed 598000 examples
# processed 599000 examples
# processed 600000 examples
# processed 601000 examples
# processed 602000 examples
# processed 603000 examples
# processed 604000 examples
# processed 605000 examples
# processed 606000 examples
# processed 607000 examples
# processed 608000 examples
# processed 609000 examples
# processed 610000 examples
# processed 611000 examples
# processed 612000 examples
# processed 613000 examples
# processed 614000 examples
# processed 615000 examples
# processed 616000 examples
# processed 617000 examples
# processed 618000 examples
# processed 619000 examples
# processed 620000 examples
# processed 621000 examples
# processed 622000 examples
# processed 623000 examples
# processed 624000 examples
# processed 625000 examples
# processed 626000 examples
# processed 627000 examples
# processed 628000 examples
# processed 629000 examples
# processed 630000 examples
# processed 631000 examples
# processed 632000 examples
# processed 633000 examples
# processed 634000 examples
# processed 635000 examples
# processed 636000 examples
# processed 637000 examples
# processed 638000 examples
# processed 639000 examples
# processed 640000 examples
# processed 641000 examples
# processed 642000 examples
# processed 643000 examples
# processed 644000 examples
# processed 645000 examples
# processed 646000 examples
# processed 647000 examples
# processed 648000 examples
# processed 649000 examples
# processed 650000 examples
# processed 651000 examples
# processed 652000 examples
# processed 653000 examples
# processed 654000 examples
# processed 655000 examples
# processed 656000 examples
# processed 657000 examples
# processed 658000 examples
# processed 659000 examples
# processed 660000 examples
# processed 661000 examples
# processed 662000 examples
# processed 663000 examples
# processed 664000 examples
# processed 665000 examples
# processed 666000 examples
# processed 667000 examples
# processed 668000 examples
# processed 669000 examples
# processed 670000 examples
# processed 671000 examples
# processed 672000 examples
# processed 673000 examples
# processed 674000 examples
# processed 675000 examples
# processed 676000 examples
# processed 677000 examples
# processed 678000 examples
# processed 679000 examples
# processed 680000 examples
# processed 681000 examples
# processed 682000 examples
# processed 683000 examples
# processed 684000 examples
# processed 685000 examples
# processed 686000 examples
# processed 687000 examples
# processed 688000 examples
# processed 689000 examples
# processed 690000 examples
# processed 691000 examples
# processed 692000 examples
# processed 693000 examples
# processed 694000 examples
# processed 695000 examples
# processed 696000 examples
# processed 697000 examples
# processed 698000 examples
# processed 699000 examples
# processed 700000 examples
# processed 701000 examples
# processed 702000 examples
# processed 703000 examples
# processed 704000 examples
# processed 705000 examples
# processed 706000 examples
# processed 707000 examples
# processed 708000 examples
# processed 709000 examples
# processed 710000 examples
# processed 711000 examples
# processed 712000 examples
# processed 713000 examples
# processed 714000 examples
# processed 715000 examples
# processed 716000 examples
# processed 717000 examples
# processed 718000 examples
# processed 719000 examples
# processed 720000 examples
# processed 721000 examples
# processed 722000 examples
# processed 723000 examples
# processed 724000 examples
# processed 725000 examples
# processed 726000 examples
# processed 727000 examples
# processed 728000 examples
# processed 729000 examples
# processed 730000 examples
# processed 731000 examples
# processed 732000 examples
# processed 733000 examples
# processed 734000 examples
# processed 735000 examples
# processed 736000 examples
# processed 737000 examples
# processed 738000 examples
# processed 739000 examples
# processed 740000 examples
# processed 741000 examples
# processed 742000 examples
# processed 743000 examples
# processed 744000 examples
# processed 745000 examples
# processed 746000 examples
# processed 747000 examples
# processed 748000 examples
# processed 749000 examples
# processed 750000 examples
# processed 751000 examples
# processed 752000 examples
# processed 753000 examples
# processed 754000 examples
# processed 755000 examples
# processed 756000 examples
# processed 757000 examples
# processed 758000 examples
# processed 759000 examples
# processed 760000 examples
# processed 761000 examples
# processed 762000 examples
# processed 763000 examples
# processed 764000 examples
# processed 765000 examples
# processed 766000 examples
# processed 767000 examples
# processed 768000 examples
# processed 769000 examples
# processed 770000 examples
# processed 771000 examples
# processed 772000 examples
# processed 773000 examples
# processed 774000 examples
# processed 775000 examples
# processed 776000 examples
# processed 777000 examples
# processed 778000 examples
# processed 779000 examples
# processed 780000 examples
# processed 781000 examples
# processed 782000 examples
# processed 783000 examples
# processed 784000 examples
# processed 785000 examples
# processed 786000 examples
# processed 787000 examples
# processed 788000 examples
# processed 789000 examples
# processed 790000 examples
# processed 791000 examples
# processed 792000 examples
# processed 793000 examples
# processed 794000 examples
# processed 795000 examples
# processed 796000 examples
# processed 797000 examples
# processed 798000 examples
# processed 799000 examples
# processed 800000 examples
# processed 801000 examples
# processed 802000 examples
# processed 803000 examples
# processed 804000 examples
# processed 805000 examples
# processed 806000 examples
# processed 807000 examples
# processed 808000 examples
# processed 809000 examples
# processed 810000 examples
# processed 811000 examples
# processed 812000 examples
# processed 813000 examples
# processed 814000 examples
# processed 815000 examples
# processed 816000 examples
# processed 817000 examples
# processed 818000 examples
# processed 819000 examples
# processed 820000 examples
# processed 821000 examples
# processed 822000 examples
# processed 823000 examples
# processed 824000 examples
# processed 825000 examples
# processed 826000 examples
# processed 827000 examples
# processed 828000 examples
# processed 829000 examples
# processed 830000 examples
# processed 831000 examples
# processed 832000 examples
# processed 833000 examples
# processed 834000 examples
# processed 835000 examples
# processed 836000 examples
# processed 837000 examples
# processed 838000 examples
# processed 839000 examples
# processed 840000 examples
# processed 841000 examples
# processed 842000 examples
# processed 843000 examples
# processed 844000 examples
# processed 845000 examples
# processed 846000 examples
# processed 847000 examples
# processed 848000 examples
# processed 849000 examples
# processed 850000 examples
# processed 851000 examples
# processed 852000 examples
# processed 853000 examples
# processed 854000 examples
# processed 855000 examples
# processed 856000 examples
# processed 857000 examples
# processed 858000 examples
# processed 859000 examples
# processed 860000 examples
# processed 861000 examples
# processed 862000 examples
# processed 863000 examples
# processed 864000 examples
# processed 865000 examples
# processed 866000 examples
# processed 867000 examples
# processed 868000 examples
# processed 869000 examples
# processed 870000 examples
# processed 871000 examples
# processed 872000 examples
# processed 873000 examples
# processed 874000 examples
# processed 875000 examples
# processed 876000 examples
# processed 877000 examples
# processed 878000 examples
# processed 879000 examples
# processed 880000 examples
# processed 881000 examples
# processed 882000 examples
# processed 883000 examples
# processed 884000 examples
# processed 885000 examples
# processed 886000 examples
# processed 887000 examples
# processed 888000 examples
# processed 889000 examples
# processed 890000 examples
# processed 891000 examples
# processed 892000 examples
# processed 893000 examples
# processed 894000 examples
# processed 895000 examples
# processed 896000 examples
# processed 897000 examples
# processed 898000 examples
# processed 899000 examples
# processed 900000 examples
# processed 901000 examples
# processed 902000 examples
# processed 903000 examples
# processed 904000 examples
# processed 905000 examples
# processed 906000 examples
# processed 907000 examples
# processed 908000 examples
# processed 909000 examples
# processed 910000 examples
# processed 911000 examples
# processed 912000 examples
# processed 913000 examples
# processed 914000 examples
# processed 915000 examples
# processed 916000 examples
# processed 917000 examples
# processed 918000 examples
# processed 919000 examples
# processed 920000 examples
# processed 921000 examples
# processed 922000 examples
# processed 923000 examples
# processed 924000 examples
# processed 925000 examples
# processed 926000 examples
# processed 927000 examples
# processed 928000 examples
# processed 929000 examples
# processed 930000 examples
# processed 931000 examples
# processed 932000 examples
# processed 933000 examples
# processed 934000 examples
# processed 935000 examples
# processed 936000 examples
# processed 937000 examples
# processed 938000 examples
# processed 939000 examples
# processed 940000 examples
# processed 941000 examples
# processed 942000 examples
# processed 943000 examples
# processed 944000 examples
# processed 945000 examples
# processed 946000 examples
# processed 947000 examples
# processed 948000 examples
# processed 949000 examples
# processed 950000 examples
# processed 951000 examples
# processed 952000 examples
# processed 953000 examples
# processed 954000 examples
# processed 955000 examples
# processed 956000 examples
# processed 957000 examples
# processed 958000 examples
# processed 959000 examples
# processed 960000 examples
# processed 961000 examples
# processed 962000 examples
# processed 963000 examples
# processed 964000 examples
# processed 965000 examples
# processed 966000 examples
# processed 967000 examples
# processed 968000 examples
# processed 969000 examples
# processed 970000 examples
# processed 971000 examples
# processed 972000 examples
# processed 973000 examples
# processed 974000 examples
# processed 975000 examples
# processed 976000 examples
# processed 977000 examples
# processed 978000 examples
# processed 979000 examples
# processed 980000 examples
# processed 981000 examples
# processed 982000 examples
# processed 983000 examples
# processed 984000 examples
# processed 985000 examples
# processed 986000 examples
# processed 987000 examples
# processed 988000 examples
# processed 989000 examples
# processed 990000 examples
# processed 991000 examples
# processed 992000 examples
# processed 993000 examples
# processed 994000 examples
# processed 995000 examples
# processed 996000 examples
# processed 997000 examples
# processed 998000 examples
# processed 999000 examples
# processed 1000000 examples
# processed 1001000 examples
# processed 1002000 examples
# processed 1003000 examples
# processed 1004000 examples
# processed 1005000 examples
# processed 1006000 examples
# processed 1007000 examples
# processed 1008000 examples
# processed 1009000 examples
# processed 1010000 examples
# unpickled total 1010500 examples
# saved total 202100 examples only for byte
# processed 1000 examples
# processed 2000 examples
# processed 3000 examples
# processed 4000 examples
# processed 5000 examples
# processed 6000 examples
# processed 7000 examples
# processed 8000 examples
# processed 9000 examples
# processed 10000 examples
# processed 11000 examples
# processed 12000 examples
# processed 13000 examples
# processed 14000 examples
# processed 15000 examples
# processed 16000 examples
# processed 17000 examples
# processed 18000 examples
# processed 19000 examples
# processed 20000 examples
# processed 21000 examples
# processed 22000 examples
# processed 23000 examples
# processed 24000 examples
# processed 25000 examples
# processed 26000 examples
# processed 27000 examples
# processed 28000 examples
# processed 29000 examples
# processed 30000 examples
# processed 31000 examples
# processed 32000 examples
# processed 33000 examples
# processed 34000 examples
# processed 35000 examples
# processed 36000 examples
# processed 37000 examples
# processed 38000 examples
# processed 39000 examples
# processed 40000 examples
# processed 41000 examples
# processed 42000 examples
# processed 43000 examples
# processed 44000 examples
# processed 45000 examples
# processed 46000 examples
# processed 47000 examples
# processed 48000 examples
# processed 49000 examples
# processed 50000 examples
# processed 51000 examples
# processed 52000 examples
# processed 53000 examples
# processed 54000 examples
# processed 55000 examples
# processed 56000 examples
# processed 57000 examples
# processed 58000 examples
# processed 59000 examples
# processed 60000 examples
# processed 61000 examples
# processed 62000 examples
# processed 63000 examples
# processed 64000 examples
# processed 65000 examples
# processed 66000 examples
# processed 67000 examples
# processed 68000 examples
# processed 69000 examples
# processed 70000 examples
# processed 71000 examples
# processed 72000 examples
# processed 73000 examples
# processed 74000 examples
# processed 75000 examples
# processed 76000 examples
# processed 77000 examples
# processed 78000 examples
# processed 79000 examples
# processed 80000 examples
# processed 81000 examples
# processed 82000 examples
# processed 83000 examples
# processed 84000 examples
# processed 85000 examples
# processed 86000 examples
# processed 87000 examples
# processed 88000 examples
# processed 89000 examples
# processed 90000 examples
# processed 91000 examples
# processed 92000 examples
# processed 93000 examples
# processed 94000 examples
# processed 95000 examples
# processed 96000 examples
# processed 97000 examples
# processed 98000 examples
# processed 99000 examples
# processed 100000 examples
# processed 101000 examples
# processed 102000 examples
# processed 103000 examples
# processed 104000 examples
# processed 105000 examples
# processed 106000 examples
# processed 107000 examples
# processed 108000 examples
# processed 109000 examples
# processed 110000 examples
# processed 111000 examples
# processed 112000 examples
# processed 113000 examples
# processed 114000 examples
# processed 115000 examples
# processed 116000 examples
# processed 117000 examples
# processed 118000 examples
# processed 119000 examples
# processed 120000 examples
# processed 121000 examples
# processed 122000 examples
# processed 123000 examples
# processed 124000 examples
# processed 125000 examples
# processed 126000 examples
# processed 127000 examples
# processed 128000 examples
# processed 129000 examples
# processed 130000 examples
# processed 131000 examples
# processed 132000 examples
# processed 133000 examples
# processed 134000 examples
# processed 135000 examples
# processed 136000 examples
# processed 137000 examples
# processed 138000 examples
# processed 139000 examples
# processed 140000 examples
# processed 141000 examples
# processed 142000 examples
# processed 143000 examples
# processed 144000 examples
# processed 145000 examples
# processed 146000 examples
# processed 147000 examples
# processed 148000 examples
# processed 149000 examples
# processed 150000 examples
# processed 151000 examples
# processed 152000 examples
# processed 153000 examples
# processed 154000 examples
# processed 155000 examples
# processed 156000 examples
# processed 157000 examples
# processed 158000 examples
# processed 159000 examples
# processed 160000 examples
# processed 161000 examples
# processed 162000 examples
# processed 163000 examples
# processed 164000 examples
# processed 165000 examples
# processed 166000 examples
# processed 167000 examples
# processed 168000 examples
# processed 169000 examples
# processed 170000 examples
# processed 171000 examples
# processed 172000 examples
# processed 173000 examples
# processed 174000 examples
# processed 175000 examples
# processed 176000 examples
# processed 177000 examples
# processed 178000 examples
# processed 179000 examples
# processed 180000 examples
# processed 181000 examples
# processed 182000 examples
# processed 183000 examples
# processed 184000 examples
# processed 185000 examples
# processed 186000 examples
# processed 187000 examples
# processed 188000 examples
# unpickled total 188000 examples
# saved total 37600 examples only for byte
# processed 1000 examples
# processed 2000 examples
# processed 3000 examples
# processed 4000 examples
# processed 5000 examples
# processed 6000 examples
# processed 7000 examples
# processed 8000 examples
# processed 9000 examples
# processed 10000 examples
# processed 11000 examples
# processed 12000 examples
# processed 13000 examples
# processed 14000 examples
# processed 15000 examples
# processed 16000 examples
# processed 17000 examples
# processed 18000 examples
# processed 19000 examples
# processed 20000 examples
# processed 21000 examples
# processed 22000 examples
# processed 23000 examples
# processed 24000 examples
# processed 25000 examples
# processed 26000 examples
# processed 27000 examples
# processed 28000 examples
# processed 29000 examples
# processed 30000 examples
# processed 31000 examples
# processed 32000 examples
# processed 33000 examples
# processed 34000 examples
# processed 35000 examples
# processed 36000 examples
# processed 37000 examples
# processed 38000 examples
# processed 39000 examples
# processed 40000 examples
# processed 41000 examples
# processed 42000 examples
# processed 43000 examples
# processed 44000 examples
# processed 45000 examples
# processed 46000 examples
# processed 47000 examples
# processed 48000 examples
# processed 49000 examples
# processed 50000 examples
# processed 51000 examples
# processed 52000 examples
# processed 53000 examples
# processed 54000 examples
# processed 55000 examples
# processed 56000 examples
# processed 57000 examples
# processed 58000 examples
# unpickled total 58750 examples
# saved total 11750 examples only for byte

# %%
# get idx samplers
train_set_size = len(train_set)
valid_set_size = len(valid_set)
train_idxs = list(range(train_set_size))
valid_idxs = list(range(valid_set_size))
if shuffle_dataset:
    np.random.seed(random_seed)
    np.random.shuffle(train_idxs)
    np.random.shuffle(valid_idxs)

train_sampler = SubsetRandomSampler(train_idxs)
valid_sampler = SubsetRandomSampler(valid_idxs)

# get data_loaders
train_loader = DataLoader(train_set, 
                      batch_size=batch_size,
                      sampler=train_sampler
                      )
valid_loader = DataLoader(valid_set,
                        batch_size=batch_size,
                        sampler=valid_sampler
                        )
test_loader = DataLoader(test_set,
                        batch_size=batch_size,
                        shuffle = True
                        )

# %% [markdown]
# ---
# ### discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, input_font_size = 128*128, img_dim=1, disc_dim = 64):
        super(Discriminator, self).__init__()
        self.conv1 = conv2d(img_dim, disc_dim, k_size=5, stride=2, pad=2, dilation=2, lrelu=False, bn=False)
        self.conv2 = conv2d(disc_dim, disc_dim*2, k_size=5, stride=4, pad=2, dilation=2)
        self.conv3 = conv2d(disc_dim*2, disc_dim*4, k_size=4, stride=4, pad=1, dilation=1)
        self.conv4 = conv2d(disc_dim*4, disc_dim*8)
        self.conv5 = conv2d(disc_dim*8, disc_dim*8)
        self.fc1 = nn.Linear(disc_dim*8 , 1)
        

    def forward(self, images, batch_size):
        batch_size = images.shape[0]
        images = images.unsqueeze(dim=1)
        #print(images.shape) # [8, 1, 128, 128]
        h1 = self.conv1(images)
        #print(h1.shape) # [8, 64, 64, 64]
        h2 = self.conv2(h1)
        #print(h2.shape) # [8, 128, 16, 16]
        h3 = self.conv3(h2)
        #print(h3.shape) # [8, 256, 4, 4]
        h4 = self.conv4(h3)        
        #print(h4.shape) # [8, 512, 2, 2]
        h5 = self.conv5(h4)        
        #print(h5.shape)
        out = torch.sigmoid(self.fc1(h5.reshape(batch_size, -1)))
        
        return out.squeeze()

# %% [markdown]
# ---
# ### generator

# %%
embedded_dim = 148 ; gen_dim = 64
class Generator(nn.Module):
    def __init__(self, img_dim =1, embedded_dim = 148, conv_dim = 64):
        super(Generator, self).__init__()
        self.deconv1 = deconv2d(embedded_dim, conv_dim * 8, k_size=4, dilation=2, stride=2)
        self.deconv2 = deconv2d(conv_dim * 8, conv_dim * 4, k_size=4, dilation=2, stride=2)
        self.deconv3 = deconv2d(conv_dim * 4, conv_dim * 2, k_size=6, dilation=2, stride=4)
        self.deconv4 = deconv2d(conv_dim * 2, conv_dim * 1, k_size=6, dilation=2, stride=4)
        self.deconv5 = deconv2d(conv_dim * 1, img_dim, k_size=4, dilation=2, stride=2, bn=False)

        
    def forward(self, doc2vec_vector, gaussian_letter_vector, batch_size):
        input_cat = torch.cat((doc2vec_vector, gaussian_letter_vector),dim=1)
        embedded = input_cat.reshape([batch_size, embedded_dim, 1,1])   
        
        d1 = self.deconv1(embedded)
        #print(d1.shape)
        d2 = self.deconv2(d1)
        #print(d2.shape)
        d3 = self.deconv3(d2)
        #print(d3.shape)
        d4 = self.deconv4(d3)
        #print(d4.shape)
        d5 = self.deconv5(d4)
        #print(d5.shape)
        fake_target = d5.squeeze(dim=1)

        return fake_target

# %%
discriminator = Discriminator().cuda()
generator = Generator().cuda()

# %%
mse_criterion = nn.MSELoss().cuda()
bce_criterion = nn.BCELoss().cuda()
l1_criterion = nn.L1Loss().cuda

# %%
d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = torch.optim.Adam(generator.parameters(), lr=lr)

# %%
def train_discriminator(temp_batch_size, generator, discriminator, images, \
                        doc2vec_Vector, gaussian_letter_vector):
    d_optimizer.zero_grad()
    
    #train with the real image
    outputs = discriminator(images, temp_batch_size)
    real_loss = F.binary_cross_entropy(outputs, Variable(torch.ones(temp_batch_size)).cuda()) 
    real_score = outputs 
        
    #train with the fake image
    fake_images = generator(doc2vec_vector, gaussian_letter_vector, temp_batch_size) 
    outputs = discriminator(fake_images, temp_batch_size)    
    fake_loss = F.binary_cross_entropy(outputs, Variable(torch.zeros(temp_batch_size)).cuda()) 
    fake_score = outputs 

    d_loss = real_loss + fake_loss 
    d_loss.backward() 
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %%
def train_generator(temp_batch_size, gaussian_letter_vector, doc2vec_vector, \
                    images, generator, discriminator):

    g_optimizer.zero_grad()
    
    # Sample again for the generator and get output from discriminator
    fake_images = generator(doc2vec_vector, gaussian_letter_vector, temp_batch_size) 
    outputs = discriminator(fake_images, temp_batch_size)

    g_l1_loss= F.l1_loss(fake_images, images)
    g_bce_loss = F.binary_cross_entropy(outputs, Variable(torch.ones(temp_batch_size)).cuda())
    
    g_loss = g_l1_loss + g_bce_loss
    g_loss.backward()
    g_optimizer.step()
    
    return g_loss, g_l1_loss

# %%
def valid_discriminator(temp_batch_size, generator, discriminator, images, \
                        doc2vec_Vector, gaussian_letter_vector):
    #train with the real image
    outputs = discriminator(images, temp_batch_size)
    real_loss = F.binary_cross_entropy(outputs, Variable(torch.ones(temp_batch_size)).cuda()) 
    real_score = outputs 
        
    #train with the fake image
    fake_images = generator(doc2vec_vector, gaussian_letter_vector, temp_batch_size) 
    outputs = discriminator(fake_images, temp_batch_size)    
    fake_loss = F.binary_cross_entropy(outputs, Variable(torch.zeros(temp_batch_size)).cuda()) 
    fake_score = outputs 

    d_loss = real_loss + fake_loss 
    
    return d_loss, real_score, fake_score

# %%
def valid_generator(temp_batch_size, gaussian_letter_vector, doc2vec_vector, \
                    images, generator, discriminator):
    
    # Sample again for the generator and get output from discriminator
    fake_images = generator(doc2vec_vector, gaussian_letter_vector, temp_batch_size) 
    outputs = discriminator(fake_images, temp_batch_size)

    g_l1_loss= F.l1_loss(fake_images, images)
    g_bce_loss = F.binary_cross_entropy(outputs, Variable(torch.ones(temp_batch_size)).cuda())
    
    g_loss = g_l1_loss + g_bce_loss
    
    return g_loss, g_l1_loss

# %%
np.random.seed(seed=304)
random_table = np.random.normal(size=[2350,128])

# %%
# set number of epochs and initialize figure counter
num_epochs = 100
num_batches = len(train_loader)
num_fig = 0

final_g_total_loss = []
final_g_l1_loss = []
final_d_loss = []

final_g_total_loss_v = []
final_g_l1_loss_v = []
final_d_loss_v = []

for epoch in range(num_epochs):
    temp_g_total_loss = []
    temp_g_l1_loss = []
    temp_d_loss = []
    
    temp_g_total_loss_v = []
    temp_g_l1_loss_v = []
    temp_d_loss_v = []

    if epoch % 1 == 0:
        print('----------------------------%d epoch----------------------------------'%(epoch+1))
    
    for n, (vectors, font) in enumerate(train_loader):
        doc2vec_vector = vectors['font_doc2vec']
        letter_vector = vectors['word_index']
        gaussian_letter_vector = random_table[letter_vector] 

        images = font.float().to(device)
        doc2vec_vector = doc2vec_vector.float().to(device)
        gaussian_letter_vector = torch.from_numpy(gaussian_letter_vector).float().to(device)
        temp_batch_size = letter_vector.size()[0]
    
        # Train the discriminator
        d_loss, real_score, fake_score =train_discriminator(temp_batch_size, generator, discriminator, \
                                                            images, doc2vec_vector, gaussian_letter_vector)
       
        
        # Train the generator
        g_loss, g_l1_loss = train_generator(temp_batch_size, gaussian_letter_vector, doc2vec_vector, \
                                            images, generator, discriminator)
                 
        temp_g_total_loss.append(g_loss.item())
        temp_g_l1_loss.append(g_l1_loss.item())
        temp_d_loss.append(d_loss.item())
        

        if n % 1000 == 0:
            final_g_total_loss.append(np.mean(temp_g_total_loss))
            final_g_l1_loss.append(np.mean(temp_g_l1_loss))
            final_d_loss.append(np.mean(temp_d_loss))       

            print('Epoch [%d/%d], Step[%d/%d], d_loss: %.4f, g_loss: %.4f, ' 
                  'D(x): %.2f, D(G(z)): %.2f' 
                  %(epoch + 1, num_epochs, n+1, num_batches, np.mean(final_d_loss),np.mean(final_g_total_loss),
                    real_score.data.mean(), fake_score.data.mean()))
        
    # validation part
    for n, (vectors, font) in enumerate(valid_loader):
        
        doc2vec_vector = vectors['font_doc2vec']
        letter_vector = vectors['word_index']
        gaussian_letter_vector = random_table[letter_vector] 

        images = font.float().to(device)
        doc2vec_vector = doc2vec_vector.float().to(device)
        gaussian_letter_vector = torch.from_numpy(gaussian_letter_vector).float().to(device)
        temp_batch_size = letter_vector.size()[0]
        
        # Train the discriminator
        d_loss, real_score, fake_score =valid_discriminator(temp_batch_size, generator, discriminator, \
                                                            images, doc2vec_vector, gaussian_letter_vector)
       
        
        # Train the generator
        g_loss, g_l1_loss = valid_generator(temp_batch_size, gaussian_letter_vector, doc2vec_vector, \
                                            images, generator, discriminator)
        
        temp_g_total_loss_v.append(g_loss.item())
        temp_g_l1_loss_v.append(g_l1_loss.item())
        temp_d_loss_v.append(d_loss.item())



        if n % 1000 == 0:

            final_g_total_loss_v.append(np.mean(temp_g_total_loss_v))
            final_g_l1_loss_v.append(np.mean(temp_g_l1_loss_v))
            final_d_loss_v.append(np.mean(temp_d_loss_v))       

            print('Epoch [%d/%d], Step[%d/%d], valid_d_loss: %.4f, valid_g_loss: %.4f, ' 
                  'D(x): %.2f, D(G(z)): %.2f' 
                  %(epoch + 1, num_epochs, n+1, num_batches, np.mean(final_d_loss_v),np.mean(final_g_total_loss_v),
                    real_score.data.mean(), fake_score.data.mean()))
# Out:
# ----------------------------1 epoch----------------------------------
# Epoch [1/100], Step[1/25263], d_loss: 1.5419, g_loss: 3.3499, D(x): 0.51, D(G(z)): 0.51
# Epoch [1/100], Step[1001/25263], d_loss: 1.4752, g_loss: 2.1657, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[2001/25263], d_loss: 1.4494, g_loss: 1.7350, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[3001/25263], d_loss: 1.4355, g_loss: 1.5104, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[4001/25263], d_loss: 1.4268, g_loss: 1.3719, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[5001/25263], d_loss: 1.4209, g_loss: 1.2777, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[6001/25263], d_loss: 1.4165, g_loss: 1.2092, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[7001/25263], d_loss: 1.4131, g_loss: 1.1572, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[8001/25263], d_loss: 1.4105, g_loss: 1.1162, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[9001/25263], d_loss: 1.4083, g_loss: 1.0832, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[10001/25263], d_loss: 1.4065, g_loss: 1.0559, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[11001/25263], d_loss: 1.4050, g_loss: 1.0329, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[12001/25263], d_loss: 1.4037, g_loss: 1.0134, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[13001/25263], d_loss: 1.4026, g_loss: 0.9965, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[14001/25263], d_loss: 1.4016, g_loss: 0.9818, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[15001/25263], d_loss: 1.4008, g_loss: 0.9689, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[16001/25263], d_loss: 1.4000, g_loss: 0.9574, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[17001/25263], d_loss: 1.3993, g_loss: 0.9471, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[18001/25263], d_loss: 1.3987, g_loss: 0.9379, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[19001/25263], d_loss: 1.3981, g_loss: 0.9296, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[20001/25263], d_loss: 1.3976, g_loss: 0.9220, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[21001/25263], d_loss: 1.3972, g_loss: 0.9151, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[22001/25263], d_loss: 1.3967, g_loss: 0.9087, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[23001/25263], d_loss: 1.3964, g_loss: 0.9029, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[24001/25263], d_loss: 1.3960, g_loss: 0.8975, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[25001/25263], d_loss: 1.3957, g_loss: 0.8925, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7468, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7490, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7497, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [1/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# ----------------------------2 epoch----------------------------------
# Epoch [2/100], Step[1/25263], d_loss: 1.3953, g_loss: 0.8879, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[1001/25263], d_loss: 1.3950, g_loss: 0.8833, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[2001/25263], d_loss: 1.3947, g_loss: 0.8789, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[3001/25263], d_loss: 1.3944, g_loss: 0.8748, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[4001/25263], d_loss: 1.3941, g_loss: 0.8710, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[5001/25263], d_loss: 1.3939, g_loss: 0.8675, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[6001/25263], d_loss: 1.3937, g_loss: 0.8641, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[7001/25263], d_loss: 1.3935, g_loss: 0.8610, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[8001/25263], d_loss: 1.3932, g_loss: 0.8580, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[9001/25263], d_loss: 1.3931, g_loss: 0.8552, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[10001/25263], d_loss: 1.3929, g_loss: 0.8526, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[11001/25263], d_loss: 1.3927, g_loss: 0.8501, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[12001/25263], d_loss: 1.3925, g_loss: 0.8477, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[13001/25263], d_loss: 1.3924, g_loss: 0.8454, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[14001/25263], d_loss: 1.3922, g_loss: 0.8433, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[15001/25263], d_loss: 1.3921, g_loss: 0.8412, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[16001/25263], d_loss: 1.3920, g_loss: 0.8393, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[17001/25263], d_loss: 1.3918, g_loss: 0.8374, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[18001/25263], d_loss: 1.3917, g_loss: 0.8356, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[19001/25263], d_loss: 1.3916, g_loss: 0.8339, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[20001/25263], d_loss: 1.3915, g_loss: 0.8323, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[21001/25263], d_loss: 1.3914, g_loss: 0.8307, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[22001/25263], d_loss: 1.3913, g_loss: 0.8292, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[23001/25263], d_loss: 1.3912, g_loss: 0.8278, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[24001/25263], d_loss: 1.3911, g_loss: 0.8264, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[25001/25263], d_loss: 1.3910, g_loss: 0.8250, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7511, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7511, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7510, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7510, D(x): 0.50, D(G(z)): 0.50
# Epoch [2/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7510, D(x): 0.50, D(G(z)): 0.50
# ----------------------------3 epoch----------------------------------
# Epoch [3/100], Step[1/25263], d_loss: 1.3909, g_loss: 0.8238, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[1001/25263], d_loss: 1.3908, g_loss: 0.8226, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[2001/25263], d_loss: 1.3907, g_loss: 0.8214, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[3001/25263], d_loss: 1.3906, g_loss: 0.8202, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[4001/25263], d_loss: 1.3906, g_loss: 0.8191, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[5001/25263], d_loss: 1.3905, g_loss: 0.8180, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[6001/25263], d_loss: 1.3904, g_loss: 0.8170, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[7001/25263], d_loss: 1.3904, g_loss: 0.8160, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[8001/25263], d_loss: 1.3903, g_loss: 0.8150, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[9001/25263], d_loss: 1.3902, g_loss: 0.8141, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[10001/25263], d_loss: 1.3902, g_loss: 0.8132, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[11001/25263], d_loss: 1.3901, g_loss: 0.8123, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[12001/25263], d_loss: 1.3900, g_loss: 0.8114, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[13001/25263], d_loss: 1.3900, g_loss: 0.8106, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[14001/25263], d_loss: 1.3899, g_loss: 0.8098, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[15001/25263], d_loss: 1.3899, g_loss: 0.8090, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[16001/25263], d_loss: 1.3898, g_loss: 0.8082, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[17001/25263], d_loss: 1.3898, g_loss: 0.8075, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[18001/25263], d_loss: 1.3897, g_loss: 0.8068, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[19001/25263], d_loss: 1.3897, g_loss: 0.8061, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[20001/25263], d_loss: 1.3896, g_loss: 0.8054, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[21001/25263], d_loss: 1.3896, g_loss: 0.8047, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[22001/25263], d_loss: 1.3895, g_loss: 0.8041, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[23001/25263], d_loss: 1.3895, g_loss: 0.8035, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[24001/25263], d_loss: 1.3895, g_loss: 0.8029, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[25001/25263], d_loss: 1.3894, g_loss: 0.8023, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7505, D(x): 0.50, D(G(z)): 0.50
# Epoch [3/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# ----------------------------4 epoch----------------------------------
# Epoch [4/100], Step[1/25263], d_loss: 1.3894, g_loss: 0.8016, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[1001/25263], d_loss: 1.3893, g_loss: 0.8010, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[2001/25263], d_loss: 1.3893, g_loss: 0.8005, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[3001/25263], d_loss: 1.3893, g_loss: 0.7999, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[4001/25263], d_loss: 1.3892, g_loss: 0.7994, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[5001/25263], d_loss: 1.3892, g_loss: 0.7989, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[6001/25263], d_loss: 1.3892, g_loss: 0.7984, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[7001/25263], d_loss: 1.3891, g_loss: 0.7979, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[8001/25263], d_loss: 1.3891, g_loss: 0.7974, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[9001/25263], d_loss: 1.3891, g_loss: 0.7970, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[10001/25263], d_loss: 1.3890, g_loss: 0.7965, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[11001/25263], d_loss: 1.3890, g_loss: 0.7961, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[12001/25263], d_loss: 1.3890, g_loss: 0.7956, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[13001/25263], d_loss: 1.3889, g_loss: 0.7952, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[14001/25263], d_loss: 1.3889, g_loss: 0.7948, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[15001/25263], d_loss: 1.3889, g_loss: 0.7944, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[16001/25263], d_loss: 1.3889, g_loss: 0.7940, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[17001/25263], d_loss: 1.3888, g_loss: 0.7936, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[18001/25263], d_loss: 1.3888, g_loss: 0.7932, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[19001/25263], d_loss: 1.3888, g_loss: 0.7928, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[20001/25263], d_loss: 1.3888, g_loss: 0.7924, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[21001/25263], d_loss: 1.3887, g_loss: 0.7921, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[22001/25263], d_loss: 1.3887, g_loss: 0.7917, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[23001/25263], d_loss: 1.3887, g_loss: 0.7914, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[24001/25263], d_loss: 1.3887, g_loss: 0.7910, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[25001/25263], d_loss: 1.3886, g_loss: 0.7907, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7502, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [4/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# ----------------------------5 epoch----------------------------------
# Epoch [5/100], Step[1/25263], d_loss: 1.3886, g_loss: 0.7903, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[1001/25263], d_loss: 1.3886, g_loss: 0.7900, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[2001/25263], d_loss: 1.3886, g_loss: 0.7896, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[3001/25263], d_loss: 1.3885, g_loss: 0.7893, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[4001/25263], d_loss: 1.3885, g_loss: 0.7890, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[5001/25263], d_loss: 1.3885, g_loss: 0.7887, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[6001/25263], d_loss: 1.3885, g_loss: 0.7884, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[7001/25263], d_loss: 1.3885, g_loss: 0.7882, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[8001/25263], d_loss: 1.3884, g_loss: 0.7879, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[9001/25263], d_loss: 1.3884, g_loss: 0.7876, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[10001/25263], d_loss: 1.3884, g_loss: 0.7873, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[11001/25263], d_loss: 1.3884, g_loss: 0.7871, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[12001/25263], d_loss: 1.3884, g_loss: 0.7868, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[13001/25263], d_loss: 1.3884, g_loss: 0.7865, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[14001/25263], d_loss: 1.3883, g_loss: 0.7863, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[15001/25263], d_loss: 1.3883, g_loss: 0.7860, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[16001/25263], d_loss: 1.3883, g_loss: 0.7858, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[17001/25263], d_loss: 1.3883, g_loss: 0.7855, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[18001/25263], d_loss: 1.3883, g_loss: 0.7853, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[19001/25263], d_loss: 1.3883, g_loss: 0.7851, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[20001/25263], d_loss: 1.3882, g_loss: 0.7848, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[21001/25263], d_loss: 1.3882, g_loss: 0.7846, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[22001/25263], d_loss: 1.3882, g_loss: 0.7844, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[23001/25263], d_loss: 1.3882, g_loss: 0.7842, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[24001/25263], d_loss: 1.3882, g_loss: 0.7840, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[25001/25263], d_loss: 1.3882, g_loss: 0.7837, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7507, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7507, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7507, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7506, D(x): 0.50, D(G(z)): 0.50
# Epoch [5/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7506, D(x): 0.50, D(G(z)): 0.50
# ----------------------------6 epoch----------------------------------
# Epoch [6/100], Step[1/25263], d_loss: 1.3882, g_loss: 0.7836, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[1001/25263], d_loss: 1.3881, g_loss: 0.7834, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[2001/25263], d_loss: 1.3881, g_loss: 0.7832, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[3001/25263], d_loss: 1.3881, g_loss: 0.7830, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[4001/25263], d_loss: 1.3881, g_loss: 0.7828, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[5001/25263], d_loss: 1.3881, g_loss: 0.7826, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[6001/25263], d_loss: 1.3881, g_loss: 0.7824, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[7001/25263], d_loss: 1.3881, g_loss: 0.7823, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[8001/25263], d_loss: 1.3880, g_loss: 0.7821, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[9001/25263], d_loss: 1.3880, g_loss: 0.7819, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[10001/25263], d_loss: 1.3880, g_loss: 0.7817, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[11001/25263], d_loss: 1.3880, g_loss: 0.7815, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[12001/25263], d_loss: 1.3880, g_loss: 0.7813, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[13001/25263], d_loss: 1.3880, g_loss: 0.7812, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[14001/25263], d_loss: 1.3880, g_loss: 0.7810, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[15001/25263], d_loss: 1.3880, g_loss: 0.7808, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[16001/25263], d_loss: 1.3880, g_loss: 0.7807, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[17001/25263], d_loss: 1.3879, g_loss: 0.7805, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[18001/25263], d_loss: 1.3879, g_loss: 0.7803, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[19001/25263], d_loss: 1.3879, g_loss: 0.7802, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[20001/25263], d_loss: 1.3879, g_loss: 0.7800, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[21001/25263], d_loss: 1.3879, g_loss: 0.7799, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[22001/25263], d_loss: 1.3879, g_loss: 0.7797, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[23001/25263], d_loss: 1.3879, g_loss: 0.7795, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[24001/25263], d_loss: 1.3879, g_loss: 0.7794, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[25001/25263], d_loss: 1.3879, g_loss: 0.7792, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7505, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7505, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# Epoch [6/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# ----------------------------7 epoch----------------------------------
# Epoch [7/100], Step[1/25263], d_loss: 1.3878, g_loss: 0.7791, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[1001/25263], d_loss: 1.3878, g_loss: 0.7790, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[2001/25263], d_loss: 1.3878, g_loss: 0.7788, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[3001/25263], d_loss: 1.3878, g_loss: 0.7787, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[4001/25263], d_loss: 1.3878, g_loss: 0.7786, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[5001/25263], d_loss: 1.3878, g_loss: 0.7784, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[6001/25263], d_loss: 1.3878, g_loss: 0.7783, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[7001/25263], d_loss: 1.3878, g_loss: 0.7782, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[8001/25263], d_loss: 1.3878, g_loss: 0.7780, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[9001/25263], d_loss: 1.3878, g_loss: 0.7779, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[10001/25263], d_loss: 1.3878, g_loss: 0.7778, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[11001/25263], d_loss: 1.3877, g_loss: 0.7776, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[12001/25263], d_loss: 1.3877, g_loss: 0.7775, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[13001/25263], d_loss: 1.3877, g_loss: 0.7774, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[14001/25263], d_loss: 1.3877, g_loss: 0.7772, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[15001/25263], d_loss: 1.3877, g_loss: 0.7771, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[16001/25263], d_loss: 1.3877, g_loss: 0.7770, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[17001/25263], d_loss: 1.3877, g_loss: 0.7769, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[18001/25263], d_loss: 1.3877, g_loss: 0.7768, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[19001/25263], d_loss: 1.3877, g_loss: 0.7766, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[20001/25263], d_loss: 1.3877, g_loss: 0.7765, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[21001/25263], d_loss: 1.3877, g_loss: 0.7764, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[22001/25263], d_loss: 1.3877, g_loss: 0.7763, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[23001/25263], d_loss: 1.3876, g_loss: 0.7762, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[24001/25263], d_loss: 1.3876, g_loss: 0.7761, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[25001/25263], d_loss: 1.3876, g_loss: 0.7760, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7504, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7503, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7503, D(x): 0.50, D(G(z)): 0.50
# Epoch [7/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7503, D(x): 0.50, D(G(z)): 0.50
# ----------------------------8 epoch----------------------------------
# Epoch [8/100], Step[1/25263], d_loss: 1.3876, g_loss: 0.7759, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[1001/25263], d_loss: 1.3876, g_loss: 0.7758, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[2001/25263], d_loss: 1.3876, g_loss: 0.7757, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[3001/25263], d_loss: 1.3876, g_loss: 0.7756, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[4001/25263], d_loss: 1.3876, g_loss: 0.7755, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[5001/25263], d_loss: 1.3876, g_loss: 0.7754, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[6001/25263], d_loss: 1.3876, g_loss: 0.7753, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[7001/25263], d_loss: 1.3876, g_loss: 0.7752, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[8001/25263], d_loss: 1.3876, g_loss: 0.7751, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[9001/25263], d_loss: 1.3876, g_loss: 0.7750, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[10001/25263], d_loss: 1.3876, g_loss: 0.7749, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[11001/25263], d_loss: 1.3875, g_loss: 0.7748, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[12001/25263], d_loss: 1.3875, g_loss: 0.7747, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[13001/25263], d_loss: 1.3875, g_loss: 0.7746, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[14001/25263], d_loss: 1.3875, g_loss: 0.7745, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[15001/25263], d_loss: 1.3875, g_loss: 0.7744, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[16001/25263], d_loss: 1.3875, g_loss: 0.7743, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[17001/25263], d_loss: 1.3875, g_loss: 0.7742, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[18001/25263], d_loss: 1.3875, g_loss: 0.7741, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[19001/25263], d_loss: 1.3875, g_loss: 0.7740, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[20001/25263], d_loss: 1.3875, g_loss: 0.7739, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[21001/25263], d_loss: 1.3875, g_loss: 0.7739, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[22001/25263], d_loss: 1.3875, g_loss: 0.7738, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[23001/25263], d_loss: 1.3875, g_loss: 0.7737, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[24001/25263], d_loss: 1.3875, g_loss: 0.7736, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[25001/25263], d_loss: 1.3875, g_loss: 0.7735, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [8/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# ----------------------------9 epoch----------------------------------
# Epoch [9/100], Step[1/25263], d_loss: 1.3875, g_loss: 0.7735, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[1001/25263], d_loss: 1.3875, g_loss: 0.7734, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[2001/25263], d_loss: 1.3874, g_loss: 0.7733, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[3001/25263], d_loss: 1.3874, g_loss: 0.7732, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[4001/25263], d_loss: 1.3874, g_loss: 0.7731, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[5001/25263], d_loss: 1.3874, g_loss: 0.7731, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[6001/25263], d_loss: 1.3874, g_loss: 0.7730, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[7001/25263], d_loss: 1.3874, g_loss: 0.7729, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[8001/25263], d_loss: 1.3874, g_loss: 0.7728, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[9001/25263], d_loss: 1.3874, g_loss: 0.7727, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[10001/25263], d_loss: 1.3874, g_loss: 0.7727, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[11001/25263], d_loss: 1.3874, g_loss: 0.7726, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[12001/25263], d_loss: 1.3874, g_loss: 0.7725, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[13001/25263], d_loss: 1.3874, g_loss: 0.7724, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[14001/25263], d_loss: 1.3874, g_loss: 0.7724, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[15001/25263], d_loss: 1.3874, g_loss: 0.7723, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[16001/25263], d_loss: 1.3874, g_loss: 0.7722, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[17001/25263], d_loss: 1.3874, g_loss: 0.7721, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[18001/25263], d_loss: 1.3874, g_loss: 0.7721, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[19001/25263], d_loss: 1.3874, g_loss: 0.7720, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[20001/25263], d_loss: 1.3874, g_loss: 0.7719, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[21001/25263], d_loss: 1.3874, g_loss: 0.7719, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[22001/25263], d_loss: 1.3873, g_loss: 0.7718, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[23001/25263], d_loss: 1.3873, g_loss: 0.7717, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[24001/25263], d_loss: 1.3873, g_loss: 0.7717, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[25001/25263], d_loss: 1.3873, g_loss: 0.7716, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [9/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# ----------------------------10 epoch----------------------------------
# Epoch [10/100], Step[1/25263], d_loss: 1.3873, g_loss: 0.7715, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[1001/25263], d_loss: 1.3873, g_loss: 0.7715, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[2001/25263], d_loss: 1.3873, g_loss: 0.7714, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[3001/25263], d_loss: 1.3873, g_loss: 0.7713, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[4001/25263], d_loss: 1.3873, g_loss: 0.7713, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[5001/25263], d_loss: 1.3873, g_loss: 0.7712, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[6001/25263], d_loss: 1.3873, g_loss: 0.7711, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[7001/25263], d_loss: 1.3873, g_loss: 0.7711, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[8001/25263], d_loss: 1.3873, g_loss: 0.7710, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[9001/25263], d_loss: 1.3873, g_loss: 0.7710, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[10001/25263], d_loss: 1.3873, g_loss: 0.7709, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[11001/25263], d_loss: 1.3873, g_loss: 0.7708, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[12001/25263], d_loss: 1.3873, g_loss: 0.7708, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[13001/25263], d_loss: 1.3873, g_loss: 0.7707, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[14001/25263], d_loss: 1.3873, g_loss: 0.7707, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[15001/25263], d_loss: 1.3873, g_loss: 0.7706, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[16001/25263], d_loss: 1.3873, g_loss: 0.7705, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[17001/25263], d_loss: 1.3873, g_loss: 0.7705, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[18001/25263], d_loss: 1.3873, g_loss: 0.7704, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[19001/25263], d_loss: 1.3873, g_loss: 0.7704, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[20001/25263], d_loss: 1.3872, g_loss: 0.7703, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[21001/25263], d_loss: 1.3872, g_loss: 0.7703, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[22001/25263], d_loss: 1.3872, g_loss: 0.7702, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[23001/25263], d_loss: 1.3872, g_loss: 0.7701, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[24001/25263], d_loss: 1.3872, g_loss: 0.7701, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[25001/25263], d_loss: 1.3872, g_loss: 0.7700, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7502, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7502, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7502, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7502, D(x): 0.50, D(G(z)): 0.50
# Epoch [10/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7502, D(x): 0.50, D(G(z)): 0.50
# ----------------------------11 epoch----------------------------------
# Epoch [11/100], Step[1/25263], d_loss: 1.3872, g_loss: 0.7700, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[1001/25263], d_loss: 1.3872, g_loss: 0.7699, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[2001/25263], d_loss: 1.3872, g_loss: 0.7699, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[3001/25263], d_loss: 1.3872, g_loss: 0.7698, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[4001/25263], d_loss: 1.3872, g_loss: 0.7698, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[5001/25263], d_loss: 1.3872, g_loss: 0.7697, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[6001/25263], d_loss: 1.3872, g_loss: 0.7697, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[7001/25263], d_loss: 1.3872, g_loss: 0.7696, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[8001/25263], d_loss: 1.3872, g_loss: 0.7696, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[9001/25263], d_loss: 1.3872, g_loss: 0.7695, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[10001/25263], d_loss: 1.3872, g_loss: 0.7695, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[11001/25263], d_loss: 1.3872, g_loss: 0.7694, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[12001/25263], d_loss: 1.3872, g_loss: 0.7694, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[13001/25263], d_loss: 1.3872, g_loss: 0.7693, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[14001/25263], d_loss: 1.3872, g_loss: 0.7693, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[15001/25263], d_loss: 1.3872, g_loss: 0.7692, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[16001/25263], d_loss: 1.3872, g_loss: 0.7692, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[17001/25263], d_loss: 1.3872, g_loss: 0.7691, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[18001/25263], d_loss: 1.3872, g_loss: 0.7691, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[19001/25263], d_loss: 1.3872, g_loss: 0.7690, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[20001/25263], d_loss: 1.3872, g_loss: 0.7690, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[21001/25263], d_loss: 1.3872, g_loss: 0.7689, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[22001/25263], d_loss: 1.3872, g_loss: 0.7689, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[23001/25263], d_loss: 1.3872, g_loss: 0.7688, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[24001/25263], d_loss: 1.3871, g_loss: 0.7688, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[25001/25263], d_loss: 1.3871, g_loss: 0.7688, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [11/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# ----------------------------12 epoch----------------------------------
# Epoch [12/100], Step[1/25263], d_loss: 1.3871, g_loss: 0.7687, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[1001/25263], d_loss: 1.3871, g_loss: 0.7686, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[2001/25263], d_loss: 1.3871, g_loss: 0.7686, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[3001/25263], d_loss: 1.3871, g_loss: 0.7686, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[4001/25263], d_loss: 1.3871, g_loss: 0.7685, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[5001/25263], d_loss: 1.3871, g_loss: 0.7685, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[6001/25263], d_loss: 1.3871, g_loss: 0.7684, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[7001/25263], d_loss: 1.3871, g_loss: 0.7684, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[8001/25263], d_loss: 1.3871, g_loss: 0.7683, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[9001/25263], d_loss: 1.3871, g_loss: 0.7683, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[10001/25263], d_loss: 1.3871, g_loss: 0.7683, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[11001/25263], d_loss: 1.3871, g_loss: 0.7682, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[12001/25263], d_loss: 1.3871, g_loss: 0.7682, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[13001/25263], d_loss: 1.3871, g_loss: 0.7681, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[14001/25263], d_loss: 1.3871, g_loss: 0.7681, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[15001/25263], d_loss: 1.3871, g_loss: 0.7681, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[16001/25263], d_loss: 1.3871, g_loss: 0.7680, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[17001/25263], d_loss: 1.3871, g_loss: 0.7680, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[18001/25263], d_loss: 1.3871, g_loss: 0.7679, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[19001/25263], d_loss: 1.3871, g_loss: 0.7679, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[20001/25263], d_loss: 1.3871, g_loss: 0.7679, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[21001/25263], d_loss: 1.3871, g_loss: 0.7678, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[22001/25263], d_loss: 1.3871, g_loss: 0.7678, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[23001/25263], d_loss: 1.3871, g_loss: 0.7677, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[24001/25263], d_loss: 1.3871, g_loss: 0.7677, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[25001/25263], d_loss: 1.3871, g_loss: 0.7677, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [12/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# ----------------------------13 epoch----------------------------------
# Epoch [13/100], Step[1/25263], d_loss: 1.3871, g_loss: 0.7676, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[1001/25263], d_loss: 1.3871, g_loss: 0.7676, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[2001/25263], d_loss: 1.3871, g_loss: 0.7675, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[3001/25263], d_loss: 1.3871, g_loss: 0.7675, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[4001/25263], d_loss: 1.3871, g_loss: 0.7675, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[5001/25263], d_loss: 1.3871, g_loss: 0.7674, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[6001/25263], d_loss: 1.3871, g_loss: 0.7674, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[7001/25263], d_loss: 1.3871, g_loss: 0.7674, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[8001/25263], d_loss: 1.3871, g_loss: 0.7673, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[9001/25263], d_loss: 1.3871, g_loss: 0.7673, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[10001/25263], d_loss: 1.3870, g_loss: 0.7673, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[11001/25263], d_loss: 1.3870, g_loss: 0.7672, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[12001/25263], d_loss: 1.3870, g_loss: 0.7672, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[13001/25263], d_loss: 1.3870, g_loss: 0.7672, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[14001/25263], d_loss: 1.3870, g_loss: 0.7671, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[15001/25263], d_loss: 1.3870, g_loss: 0.7671, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[16001/25263], d_loss: 1.3870, g_loss: 0.7671, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[17001/25263], d_loss: 1.3870, g_loss: 0.7670, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[18001/25263], d_loss: 1.3870, g_loss: 0.7670, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[19001/25263], d_loss: 1.3870, g_loss: 0.7670, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[20001/25263], d_loss: 1.3870, g_loss: 0.7669, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[21001/25263], d_loss: 1.3870, g_loss: 0.7669, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[22001/25263], d_loss: 1.3870, g_loss: 0.7669, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[23001/25263], d_loss: 1.3870, g_loss: 0.7668, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[24001/25263], d_loss: 1.3870, g_loss: 0.7668, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[25001/25263], d_loss: 1.3870, g_loss: 0.7668, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [13/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# ----------------------------14 epoch----------------------------------
# Epoch [14/100], Step[1/25263], d_loss: 1.3870, g_loss: 0.7667, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[1001/25263], d_loss: 1.3870, g_loss: 0.7667, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[2001/25263], d_loss: 1.3870, g_loss: 0.7667, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[3001/25263], d_loss: 1.3870, g_loss: 0.7666, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[4001/25263], d_loss: 1.3870, g_loss: 0.7666, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[5001/25263], d_loss: 1.3870, g_loss: 0.7666, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[6001/25263], d_loss: 1.3870, g_loss: 0.7665, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[7001/25263], d_loss: 1.3870, g_loss: 0.7665, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[8001/25263], d_loss: 1.3870, g_loss: 0.7665, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[9001/25263], d_loss: 1.3870, g_loss: 0.7664, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[10001/25263], d_loss: 1.3870, g_loss: 0.7664, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[11001/25263], d_loss: 1.3870, g_loss: 0.7664, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[12001/25263], d_loss: 1.3870, g_loss: 0.7663, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[13001/25263], d_loss: 1.3870, g_loss: 0.7663, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[14001/25263], d_loss: 1.3870, g_loss: 0.7663, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[15001/25263], d_loss: 1.3870, g_loss: 0.7663, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[16001/25263], d_loss: 1.3870, g_loss: 0.7662, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[17001/25263], d_loss: 1.3870, g_loss: 0.7662, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[18001/25263], d_loss: 1.3870, g_loss: 0.7662, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[19001/25263], d_loss: 1.3870, g_loss: 0.7661, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[20001/25263], d_loss: 1.3870, g_loss: 0.7661, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[21001/25263], d_loss: 1.3870, g_loss: 0.7661, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[22001/25263], d_loss: 1.3870, g_loss: 0.7661, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[23001/25263], d_loss: 1.3870, g_loss: 0.7660, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[24001/25263], d_loss: 1.3870, g_loss: 0.7660, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[25001/25263], d_loss: 1.3870, g_loss: 0.7660, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [14/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7497, D(x): 0.50, D(G(z)): 0.50
# ----------------------------15 epoch----------------------------------
# Epoch [15/100], Step[1/25263], d_loss: 1.3870, g_loss: 0.7659, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[1001/25263], d_loss: 1.3870, g_loss: 0.7659, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[2001/25263], d_loss: 1.3870, g_loss: 0.7659, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[3001/25263], d_loss: 1.3870, g_loss: 0.7658, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[4001/25263], d_loss: 1.3870, g_loss: 0.7658, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[5001/25263], d_loss: 1.3870, g_loss: 0.7658, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[6001/25263], d_loss: 1.3870, g_loss: 0.7658, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[7001/25263], d_loss: 1.3869, g_loss: 0.7657, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[8001/25263], d_loss: 1.3869, g_loss: 0.7657, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[9001/25263], d_loss: 1.3869, g_loss: 0.7657, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[10001/25263], d_loss: 1.3869, g_loss: 0.7657, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[11001/25263], d_loss: 1.3869, g_loss: 0.7656, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[12001/25263], d_loss: 1.3869, g_loss: 0.7656, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[13001/25263], d_loss: 1.3869, g_loss: 0.7656, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[14001/25263], d_loss: 1.3869, g_loss: 0.7656, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[15001/25263], d_loss: 1.3869, g_loss: 0.7655, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[16001/25263], d_loss: 1.3869, g_loss: 0.7655, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[17001/25263], d_loss: 1.3869, g_loss: 0.7655, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[18001/25263], d_loss: 1.3869, g_loss: 0.7654, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[19001/25263], d_loss: 1.3869, g_loss: 0.7654, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[20001/25263], d_loss: 1.3869, g_loss: 0.7654, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[21001/25263], d_loss: 1.3869, g_loss: 0.7654, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[22001/25263], d_loss: 1.3869, g_loss: 0.7653, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[23001/25263], d_loss: 1.3869, g_loss: 0.7653, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[24001/25263], d_loss: 1.3869, g_loss: 0.7653, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[25001/25263], d_loss: 1.3869, g_loss: 0.7653, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [15/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# ----------------------------16 epoch----------------------------------
# Epoch [16/100], Step[1/25263], d_loss: 1.3869, g_loss: 0.7653, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[1001/25263], d_loss: 1.3869, g_loss: 0.7652, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[2001/25263], d_loss: 1.3869, g_loss: 0.7652, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[3001/25263], d_loss: 1.3869, g_loss: 0.7652, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[4001/25263], d_loss: 1.3869, g_loss: 0.7652, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[5001/25263], d_loss: 1.3869, g_loss: 0.7651, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[6001/25263], d_loss: 1.3869, g_loss: 0.7651, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[7001/25263], d_loss: 1.3869, g_loss: 0.7651, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[8001/25263], d_loss: 1.3869, g_loss: 0.7651, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[9001/25263], d_loss: 1.3869, g_loss: 0.7650, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[10001/25263], d_loss: 1.3869, g_loss: 0.7650, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[11001/25263], d_loss: 1.3869, g_loss: 0.7650, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[12001/25263], d_loss: 1.3869, g_loss: 0.7650, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[13001/25263], d_loss: 1.3869, g_loss: 0.7650, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[14001/25263], d_loss: 1.3869, g_loss: 0.7649, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[15001/25263], d_loss: 1.3869, g_loss: 0.7649, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[16001/25263], d_loss: 1.3869, g_loss: 0.7649, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[17001/25263], d_loss: 1.3869, g_loss: 0.7649, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[18001/25263], d_loss: 1.3869, g_loss: 0.7648, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[19001/25263], d_loss: 1.3869, g_loss: 0.7648, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[20001/25263], d_loss: 1.3869, g_loss: 0.7648, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[21001/25263], d_loss: 1.3869, g_loss: 0.7648, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[22001/25263], d_loss: 1.3869, g_loss: 0.7648, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[23001/25263], d_loss: 1.3869, g_loss: 0.7647, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[24001/25263], d_loss: 1.3869, g_loss: 0.7647, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[25001/25263], d_loss: 1.3869, g_loss: 0.7647, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# Epoch [16/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7498, D(x): 0.50, D(G(z)): 0.50
# ----------------------------17 epoch----------------------------------
# Epoch [17/100], Step[1/25263], d_loss: 1.3869, g_loss: 0.7647, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[1001/25263], d_loss: 1.3869, g_loss: 0.7646, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[2001/25263], d_loss: 1.3869, g_loss: 0.7646, D(x): 0.50, D(G(z)): 0.50
# ...
# Epoch [17/100], Step[9001/25263], d_loss: 1.3869, g_loss: 0.7645, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[10001/25263], d_loss: 1.3869, g_loss: 0.7645, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[11001/25263], d_loss: 1.3869, g_loss: 0.7644, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[12001/25263], d_loss: 1.3869, g_loss: 0.7644, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[13001/25263], d_loss: 1.3869, g_loss: 0.7644, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[14001/25263], d_loss: 1.3869, g_loss: 0.7644, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[15001/25263], d_loss: 1.3869, g_loss: 0.7643, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[16001/25263], d_loss: 1.3869, g_loss: 0.7643, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[17001/25263], d_loss: 1.3869, g_loss: 0.7643, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[18001/25263], d_loss: 1.3869, g_loss: 0.7643, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[19001/25263], d_loss: 1.3869, g_loss: 0.7643, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[20001/25263], d_loss: 1.3869, g_loss: 0.7643, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[21001/25263], d_loss: 1.3869, g_loss: 0.7642, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[22001/25263], d_loss: 1.3868, g_loss: 0.7642, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[23001/25263], d_loss: 1.3868, g_loss: 0.7642, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[24001/25263], d_loss: 1.3868, g_loss: 0.7642, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[25001/25263], d_loss: 1.3868, g_loss: 0.7642, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [17/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# ----------------------------18 epoch----------------------------------
# Epoch [18/100], Step[1/25263], d_loss: 1.3868, g_loss: 0.7641, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[1001/25263], d_loss: 1.3868, g_loss: 0.7641, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[2001/25263], d_loss: 1.3868, g_loss: 0.7641, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[3001/25263], d_loss: 1.3868, g_loss: 0.7641, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[4001/25263], d_loss: 1.3868, g_loss: 0.7641, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[5001/25263], d_loss: 1.3868, g_loss: 0.7640, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[6001/25263], d_loss: 1.3868, g_loss: 0.7640, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[7001/25263], d_loss: 1.3868, g_loss: 0.7640, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[8001/25263], d_loss: 1.3868, g_loss: 0.7640, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[9001/25263], d_loss: 1.3868, g_loss: 0.7640, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[10001/25263], d_loss: 1.3868, g_loss: 0.7639, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[11001/25263], d_loss: 1.3868, g_loss: 0.7639, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[12001/25263], d_loss: 1.3868, g_loss: 0.7639, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[13001/25263], d_loss: 1.3868, g_loss: 0.7639, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[14001/25263], d_loss: 1.3868, g_loss: 0.7639, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[15001/25263], d_loss: 1.3868, g_loss: 0.7639, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[16001/25263], d_loss: 1.3868, g_loss: 0.7638, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[17001/25263], d_loss: 1.3868, g_loss: 0.7638, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[18001/25263], d_loss: 1.3868, g_loss: 0.7638, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[19001/25263], d_loss: 1.3868, g_loss: 0.7638, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[20001/25263], d_loss: 1.3868, g_loss: 0.7638, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[21001/25263], d_loss: 1.3868, g_loss: 0.7637, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[22001/25263], d_loss: 1.3868, g_loss: 0.7637, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[23001/25263], d_loss: 1.3868, g_loss: 0.7637, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[24001/25263], d_loss: 1.3868, g_loss: 0.7637, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[25001/25263], d_loss: 1.3868, g_loss: 0.7637, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7501, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [18/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# ----------------------------19 epoch----------------------------------
# Epoch [19/100], Step[1/25263], d_loss: 1.3868, g_loss: 0.7637, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[1001/25263], d_loss: 1.3868, g_loss: 0.7637, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[2001/25263], d_loss: 1.3868, g_loss: 0.7637, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[3001/25263], d_loss: 1.3868, g_loss: 0.7636, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[4001/25263], d_loss: 1.3868, g_loss: 0.7636, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[5001/25263], d_loss: 1.3868, g_loss: 0.7636, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[6001/25263], d_loss: 1.3868, g_loss: 0.7636, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[7001/25263], d_loss: 1.3868, g_loss: 0.7636, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[8001/25263], d_loss: 1.3868, g_loss: 0.7635, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[9001/25263], d_loss: 1.3868, g_loss: 0.7635, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[10001/25263], d_loss: 1.3868, g_loss: 0.7635, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[11001/25263], d_loss: 1.3868, g_loss: 0.7635, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[12001/25263], d_loss: 1.3868, g_loss: 0.7635, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[13001/25263], d_loss: 1.3868, g_loss: 0.7635, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[14001/25263], d_loss: 1.3868, g_loss: 0.7635, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[15001/25263], d_loss: 1.3868, g_loss: 0.7634, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[16001/25263], d_loss: 1.3868, g_loss: 0.7634, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[17001/25263], d_loss: 1.3868, g_loss: 0.7634, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[18001/25263], d_loss: 1.3868, g_loss: 0.7634, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[19001/25263], d_loss: 1.3868, g_loss: 0.7634, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[20001/25263], d_loss: 1.3868, g_loss: 0.7634, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[21001/25263], d_loss: 1.3868, g_loss: 0.7633, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[22001/25263], d_loss: 1.3868, g_loss: 0.7633, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[23001/25263], d_loss: 1.3868, g_loss: 0.7633, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[24001/25263], d_loss: 1.3868, g_loss: 0.7633, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[25001/25263], d_loss: 1.3868, g_loss: 0.7633, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# Epoch [19/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7500, D(x): 0.50, D(G(z)): 0.50
# ----------------------------20 epoch----------------------------------
# Epoch [20/100], Step[1/25263], d_loss: 1.3868, g_loss: 0.7633, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[1001/25263], d_loss: 1.3868, g_loss: 0.7633, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[2001/25263], d_loss: 1.3868, g_loss: 0.7632, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[3001/25263], d_loss: 1.3868, g_loss: 0.7632, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[4001/25263], d_loss: 1.3868, g_loss: 0.7632, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[5001/25263], d_loss: 1.3868, g_loss: 0.7632, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[6001/25263], d_loss: 1.3868, g_loss: 0.7632, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[7001/25263], d_loss: 1.3868, g_loss: 0.7632, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[8001/25263], d_loss: 1.3868, g_loss: 0.7632, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[9001/25263], d_loss: 1.3868, g_loss: 0.7631, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[10001/25263], d_loss: 1.3868, g_loss: 0.7631, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[11001/25263], d_loss: 1.3868, g_loss: 0.7631, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[12001/25263], d_loss: 1.3868, g_loss: 0.7631, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[13001/25263], d_loss: 1.3868, g_loss: 0.7631, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[14001/25263], d_loss: 1.3868, g_loss: 0.7631, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[15001/25263], d_loss: 1.3868, g_loss: 0.7631, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[16001/25263], d_loss: 1.3868, g_loss: 0.7630, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[17001/25263], d_loss: 1.3868, g_loss: 0.7630, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[18001/25263], d_loss: 1.3868, g_loss: 0.7630, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[19001/25263], d_loss: 1.3868, g_loss: 0.7630, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[20001/25263], d_loss: 1.3868, g_loss: 0.7630, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[21001/25263], d_loss: 1.3868, g_loss: 0.7630, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[22001/25263], d_loss: 1.3868, g_loss: 0.7630, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[23001/25263], d_loss: 1.3868, g_loss: 0.7629, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[24001/25263], d_loss: 1.3868, g_loss: 0.7629, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[25001/25263], d_loss: 1.3868, g_loss: 0.7629, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# Epoch [20/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# ----------------------------21 epoch----------------------------------
# Epoch [21/100], Step[1/25263], d_loss: 1.3868, g_loss: 0.7629, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[1001/25263], d_loss: 1.3868, g_loss: 0.7629, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[2001/25263], d_loss: 1.3868, g_loss: 0.7629, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[3001/25263], d_loss: 1.3868, g_loss: 0.7629, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[4001/25263], d_loss: 1.3868, g_loss: 0.7628, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[5001/25263], d_loss: 1.3868, g_loss: 0.7628, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[6001/25263], d_loss: 1.3868, g_loss: 0.7628, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[7001/25263], d_loss: 1.3868, g_loss: 0.7628, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[8001/25263], d_loss: 1.3868, g_loss: 0.7628, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[9001/25263], d_loss: 1.3868, g_loss: 0.7628, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[10001/25263], d_loss: 1.3868, g_loss: 0.7628, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[11001/25263], d_loss: 1.3868, g_loss: 0.7627, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[12001/25263], d_loss: 1.3868, g_loss: 0.7627, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[13001/25263], d_loss: 1.3868, g_loss: 0.7627, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[14001/25263], d_loss: 1.3867, g_loss: 0.7627, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[15001/25263], d_loss: 1.3867, g_loss: 0.7627, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[16001/25263], d_loss: 1.3867, g_loss: 0.7627, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[17001/25263], d_loss: 1.3867, g_loss: 0.7627, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[18001/25263], d_loss: 1.3867, g_loss: 0.7627, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[19001/25263], d_loss: 1.3867, g_loss: 0.7626, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[20001/25263], d_loss: 1.3867, g_loss: 0.7626, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[21001/25263], d_loss: 1.3867, g_loss: 0.7626, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[22001/25263], d_loss: 1.3867, g_loss: 0.7626, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[23001/25263], d_loss: 1.3867, g_loss: 0.7626, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[24001/25263], d_loss: 1.3867, g_loss: 0.7626, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[25001/25263], d_loss: 1.3867, g_loss: 0.7626, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[1/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[1001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[2001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[3001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# Epoch [21/100], Step[4001/25263], valid_d_loss: 1.3863, valid_g_loss: 0.7499, D(x): 0.50, D(G(z)): 0.50
# ----------------------------22 epoch----------------------------------
# Epoch [22/100], Step[1/25263], d_loss: 1.3867, g_loss: 0.7625, D(x): 0.50, D(G(z)): 0.50
# Epoch [22/100], Step[1001/25263], d_loss: 1.3867, g_loss: 0.7625, D(x): 0.50, D(G(z)): 0.50
# Epoch [22/100], Step[2001/25263], d_loss: 1.3867, g_loss: 0.7625, D(x): 0.50, D(G(z)): 0.50
# Epoch [22/100], Step[3001/25263], d_loss: 1.3867, g_loss: 0.7625, D(x): 0.50, D(G(z)): 0.50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-84fcad060f16> in <module>
#      36         # Train the discriminator
#      37         d_loss, real_score, fake_score =train_discriminator(temp_batch_size, generator, discriminator, \
# ---> 38                                                             images, doc2vec_vector, gaussian_letter_vector)
#      39
#      40
#
# <ipython-input-15-8ce7dd9e8a8d> in train_discriminator(temp_batch_size, generator, discriminator, images, doc2vec_Vector, gaussian_letter_vector)
#      15
#      16     d_loss = real_loss + fake_loss
# ---> 17     d_loss.backward()
#      18     d_optimizer.step()
#      19
#
# ~/anaconda3/envs/tobigs-typo/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# ~/anaconda3/envs/tobigs-typo/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#plt.plot(final_g_total_loss)
plt.plot(final_g_total_loss)
plt.plot(final_g_l1_loss)
plt.plot(final_d_loss)
plt.show()

# %%
#plt.plot(final_g_total_loss)
plt.plot(final_g_l1_loss[100:])
plt.show()

# %%
plt.plot(final_g_l1_loss_v)
plt.show()

# %%
# save
savePath = "./cc_discriminator_0104.pth"
torch.save(discriminator.state_dict(), savePath)

# %%
savePath = "./cc_generator_0104.pth"
torch.save(generator.state_dict(), savePath)

# %%
# load
#new_model = TestModel()
#new_model.load_state_dict(torch.load("./output/test_model.pth"))

# %%
history = {'final_g_total_loss': final_g_total_loss,
            'final_g_l1_loss': final_g_l1_loss,
            'final_d_loss': final_d_loss,
           
            'final_g_total_loss_v' : final_g_total_loss_v,
            'final_g_l1_loss_v' : final_g_l1_loss_v,
            'final_d_loss_v' : final_d_loss_v,
           
            'temp_g_total_loss' : temp_g_total_loss,
            'temp_g_l1_loss' : temp_g_l1_loss,
            'temp_d_loss' : temp_d_loss,

            'temp_g_total_loss_v' : temp_g_total_loss_v,
            'temp_g_l1_loss_v' : temp_g_l1_loss_v,
            'temp_d_loss_v' : temp_d_loss_v}

# %%
import pickle
with open('ccGAN_history0104.pkl', 'wb') as f:
    pickle.dump(history, f)

# %%
with open('ccGAN_history0104.pkl', 'rb') as f:
    a = pickle.load(f)

# %% [markdown]
# ---

# %%
for i, (vectors, font) in enumerate(test_loader):

        doc2vec_vector = vectors['font_doc2vec']
        letter_vector = vectors['word_index']
        gaussian_letter_vector = random_table[letter_vector] 

        images = font.float().to(device)
        doc2vec_vector = doc2vec_vector.float().to(device)
        gaussian_letter_vector = torch.from_numpy(gaussian_letter_vector).float().to(device)
        
        temp_batch_size = letter_vector.size()[0]
        fake_images = generator(doc2vec_vector, gaussian_letter_vector, temp_batch_size) 
        if i ==0: break

# %%
fake_images_view = fake_images.view(fake_images.size(0), 128, 128)
images_view = images.view(images.size(0), 128, 128)

plt.figure(figsize=(10, 200))
for i in range(8):
    plt.subplot(50, 4, i*2+1)
    plt.imshow(images_view[i].cpu().detach().numpy())
    plt.subplot(50, 4, (i+1)*2)
    plt.imshow(fake_images_view[i].cpu().detach().numpy())
